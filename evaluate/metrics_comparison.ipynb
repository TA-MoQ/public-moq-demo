# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
# localhost:8443 - chunk_duration=0.04
testid_datagram_buffering_localhost_livestream = ''
for d in os.listdir('./downloads/datagram/localhost_8443/')[::-1]:
    if 'chrome_buffering_logs' in d:
        testid_datagram_buffering_localhost_livestream = d.split('_t_')[-1]
        break
df_datagram_buffering_localhost_livestream = pd.read_csv(f'./downloads/datagram/localhost_8443/chrome_buffering_logs_t_{testid_datagram_buffering_localhost_livestream}')
df_datagram_segment_localhost_livestream = pd.read_csv(f'./downloads/datagram/localhost_8443/chrome_segment_logs_t_{testid_datagram_buffering_localhost_livestream}')

testid_hybrid_buffering_localhost_livestream = ''
for d in os.listdir('./downloads/hybrid/localhost_8443/')[::-1]:
    if 'chrome_buffering_logs' in d:
        testid_hybrid_buffering_localhost_livestream = d.split('_t_')[-1]
        break
df_hybrid_buffering_localhost_livestream = pd.read_csv(f'./downloads/hybrid/localhost_8443/chrome_buffering_logs_t_{testid_hybrid_buffering_localhost_livestream}')
df_hybrid_segment_localhost_livestream = pd.read_csv(f'./downloads/hybrid/localhost_8443/chrome_segment_logs_t_{testid_hybrid_buffering_localhost_livestream}')

testid_stream_buffering_localhost_livestream = ''
for d in os.listdir('./downloads/stream/localhost_8443/')[::-1]:
    if 'chrome_buffering_logs' in d:
        testid_stream_buffering_localhost_livestream = d.split('_t_')[-1]
        break
df_stream_buffering_localhost_livestream = pd.read_csv(f'./downloads/stream/localhost_8443/chrome_buffering_logs_t_{testid_stream_buffering_localhost_livestream}')
df_stream_segment_localhost_livestream = pd.read_csv(f'./downloads/stream/localhost_8443/chrome_segment_logs_t_{testid_stream_buffering_localhost_livestream}')

# %%
# localhost:4443 - chunk_duration=0.04
testid_datagram_buffering_localhost_bbb = ''
for d in os.listdir('./downloads/datagram/localhost_4443/')[::-1]:
    if 'chrome_buffering_logs' in d:
        testid_datagram_buffering_localhost_bbb = d.split('_t_')[-1]
        break
df_datagram_buffering_localhost_bbb = pd.read_csv(f'./downloads/datagram/localhost_4443/chrome_buffering_logs_t_{testid_datagram_buffering_localhost_bbb}')
df_datagram_segment_localhost_bbb = pd.read_csv(f'./downloads/datagram/localhost_4443/chrome_segment_logs_t_{testid_datagram_buffering_localhost_bbb}')

testid_hybrid_buffering_localhost_bbb = ''
for d in os.listdir('./downloads/hybrid/localhost_4443/')[::-1]:
    if 'chrome_buffering_logs' in d:
        testid_hybrid_buffering_localhost_bbb = d.split('_t_')[-1]
        break
df_hybrid_buffering_localhost_bbb = pd.read_csv(f'./downloads/hybrid/localhost_4443/chrome_buffering_logs_t_{testid_hybrid_buffering_localhost_bbb}')
df_hybrid_segment_localhost_bbb = pd.read_csv(f'./downloads/hybrid/localhost_4443/chrome_segment_logs_t_{testid_hybrid_buffering_localhost_bbb}')

testid_stream_buffering_localhost_bbb = ''
for d in os.listdir('./downloads/stream/localhost_4443/')[::-1]:
    if 'chrome_buffering_logs' in d:
        testid_stream_buffering_localhost_bbb = d.split('_t_')[-1]
        break
df_stream_buffering_localhost_bbb = pd.read_csv(f'./downloads/stream/localhost_4443/chrome_buffering_logs_t_{testid_stream_buffering_localhost_bbb}')
df_stream_segment_localhost_bbb = pd.read_csv(f'./downloads/stream/localhost_4443/chrome_segment_logs_t_{testid_stream_buffering_localhost_bbb}')

# %%
# moq.rorre.me:8443 - chunk_duration=0.04
testid_datagram_buffering_hosted_livestream = ''
for d in os.listdir('./downloads/datagram/moq_rorre_me_8443/')[::-1]:
    if 'chrome_buffering_logs' in d:
        testid_datagram_buffering_hosted_livestream = d.split('_t_')[-1]
        break
df_datagram_buffering_hosted_livestream = pd.read_csv(f'./downloads/datagram/moq_rorre_me_8443/chrome_buffering_logs_t_{testid_datagram_buffering_hosted_livestream}')
df_datagram_segment_hosted_livestream = pd.read_csv(f'./downloads/datagram/moq_rorre_me_8443/chrome_segment_logs_t_{testid_datagram_buffering_hosted_livestream}')

testid_hybrid_buffering_hosted_livestream = ''
for d in os.listdir('./downloads/hybrid/moq_rorre_me_8443/')[::-1]:
    if 'chrome_buffering_logs' in d:
        testid_hybrid_buffering_hosted_livestream = d.split('_t_')[-1]
        break
df_hybrid_buffering_hosted_livestream = pd.read_csv(f'./downloads/hybrid/moq_rorre_me_8443/chrome_buffering_logs_t_{testid_hybrid_buffering_hosted_livestream}')
df_hybrid_segment_hosted_livestream = pd.read_csv(f'./downloads/hybrid/moq_rorre_me_8443/chrome_segment_logs_t_{testid_hybrid_buffering_hosted_livestream}')

testid_stream_buffering_hosted_livestream = ''
for d in os.listdir('./downloads/stream/moq_rorre_me_8443/')[::-1]:
    if 'chrome_buffering_logs' in d:
        testid_stream_buffering_hosted_livestream = d.split('_t_')[-1]
        break
df_stream_buffering_hosted_livestream = pd.read_csv(f'./downloads/stream/moq_rorre_me_8443/chrome_buffering_logs_t_{testid_stream_buffering_hosted_livestream}')
df_stream_segment_hosted_livestream = pd.read_csv(f'./downloads/stream/moq_rorre_me_8443/chrome_segment_logs_t_{testid_stream_buffering_hosted_livestream}')

# %%
# moq.rorre.me:4443 - chunk_duration=0.04
testid_datagram_buffering_hosted_bbb = ''
for d in os.listdir('./downloads/datagram/moq_rorre_me_4443/')[::-1]:
    if 'chrome_buffering_logs' in d:
        testid_datagram_buffering_hosted_bbb = d.split('_t_')[-1]
        break
df_datagram_buffering_hosted_bbb = pd.read_csv(f'./downloads/datagram/moq_rorre_me_4443/chrome_buffering_logs_t_{testid_datagram_buffering_hosted_bbb}')
df_datagram_segment_hosted_bbb = pd.read_csv(f'./downloads/datagram/moq_rorre_me_4443/chrome_segment_logs_t_{testid_datagram_buffering_hosted_bbb}')

testid_hybrid_buffering_hosted_bbb = ''
for d in os.listdir('./downloads/hybrid/moq_rorre_me_4443/')[::-1]:
    if 'chrome_buffering_logs' in d:
        testid_hybrid_buffering_hosted_bbb = d.split('_t_')[-1]
        break
df_hybrid_buffering_hosted_bbb = pd.read_csv(f'./downloads/hybrid/moq_rorre_me_4443/chrome_buffering_logs_t_{testid_hybrid_buffering_hosted_bbb}')
df_hybrid_segment_hosted_bbb = pd.read_csv(f'./downloads/hybrid/moq_rorre_me_4443/chrome_segment_logs_t_{testid_hybrid_buffering_hosted_bbb}')

testid_stream_buffering_hosted_bbb = ''
for d in os.listdir('./downloads/stream/moq_rorre_me_4443/')[::-1]:
    if 'chrome_buffering_logs' in d:
        testid_stream_buffering_hosted_bbb = d.split('_t_')[-1]
        break
df_stream_buffering_hosted_bbb = pd.read_csv(f'./downloads/stream/moq_rorre_me_4443/chrome_buffering_logs_t_{testid_stream_buffering_hosted_bbb}')
df_stream_segment_hosted_bbb = pd.read_csv(f'./downloads/stream/moq_rorre_me_4443/chrome_segment_logs_t_{testid_stream_buffering_hosted_bbb}')

# %%
buffering_metrics = [
    "videoBufferingDurationInBuffered",
    "audioBufferingDurationInBuffered",
    # "videoDurationInBuffered",
    # "audioDurationInBuffered",
    "videoBufferingCountInBuffered",
    "audioBufferingCountInBuffered",
    "videoRebufferingRatioInBuffered",
    "audioRebufferingRatioInBuffered",
    "videoBufferingCount",
    "audioBufferingCount",
    "videoTotalBufferingDuration",
    "audioTotalBufferingDuration",
    "videoTotalRebufferingRatio",
    "audioTotalRebufferingRatio",
    "overallBufferingCount",
    "overallBufferingDuration",
    "overallRebufferingRatio",
]

# %%
segment_metrics = [
    "latency",
    "jitter",
    "totalChunks"
]

# %%
# localhost:8443 - chunk_duration=0.04
df_datagram_buffering_localhost_livestream['timestamp'] = (df_datagram_buffering_localhost_livestream['timestamp'] - df_datagram_buffering_localhost_livestream['timestamp'].min()) / 1000
df_datagram_segment_localhost_livestream['timestamp'] = (df_datagram_segment_localhost_livestream['timestamp'] - df_datagram_segment_localhost_livestream['timestamp'].min())

df_hybrid_buffering_localhost_livestream['timestamp'] = (df_hybrid_buffering_localhost_livestream['timestamp'] - df_hybrid_buffering_localhost_livestream['timestamp'].min()) / 1000
df_hybrid_segment_localhost_livestream['timestamp'] = (df_hybrid_segment_localhost_livestream['timestamp'] - df_hybrid_segment_localhost_livestream['timestamp'].min())

df_stream_buffering_localhost_livestream['timestamp'] = (df_stream_buffering_localhost_livestream['timestamp'] - df_stream_buffering_localhost_livestream['timestamp'].min()) / 1000
df_stream_segment_localhost_livestream['timestamp'] = (df_stream_segment_localhost_livestream['timestamp'] - df_stream_segment_localhost_livestream['timestamp'].min())

# localhost:4443 - chunk_duration=0.04
df_datagram_buffering_localhost_bbb['timestamp'] = (df_datagram_buffering_localhost_bbb['timestamp'] - df_datagram_buffering_localhost_bbb['timestamp'].min()) / 1000
df_datagram_segment_localhost_bbb['timestamp'] = (df_datagram_segment_localhost_bbb['timestamp'] - df_datagram_segment_localhost_bbb['timestamp'].min())

df_hybrid_buffering_localhost_bbb['timestamp'] = (df_hybrid_buffering_localhost_bbb['timestamp'] - df_hybrid_buffering_localhost_bbb['timestamp'].min()) / 1000
df_hybrid_segment_localhost_bbb['timestamp'] = (df_hybrid_segment_localhost_bbb['timestamp'] - df_hybrid_segment_localhost_bbb['timestamp'].min())

df_stream_buffering_localhost_bbb['timestamp'] = (df_stream_buffering_localhost_bbb['timestamp'] - df_stream_buffering_localhost_bbb['timestamp'].min()) / 1000
df_stream_segment_localhost_bbb['timestamp'] = (df_stream_segment_localhost_bbb['timestamp'] - df_stream_segment_localhost_bbb['timestamp'].min())

# moq.rorre.me:4443 - chunk_duration=0.04
df_datagram_buffering_hosted_bbb['timestamp'] = (df_datagram_buffering_hosted_bbb['timestamp'] - df_datagram_buffering_hosted_bbb['timestamp'].min()) / 1000
df_datagram_segment_hosted_bbb['timestamp'] = (df_datagram_segment_hosted_bbb['timestamp'] - df_datagram_segment_hosted_bbb['timestamp'].min())

df_hybrid_buffering_hosted_bbb['timestamp'] = (df_hybrid_buffering_hosted_bbb['timestamp'] - df_hybrid_buffering_hosted_bbb['timestamp'].min()) / 1000
df_hybrid_segment_hosted_bbb['timestamp'] = (df_hybrid_segment_hosted_bbb['timestamp'] - df_hybrid_segment_hosted_bbb['timestamp'].min())

df_stream_buffering_hosted_bbb['timestamp'] = (df_stream_buffering_hosted_bbb['timestamp'] - df_stream_buffering_hosted_bbb['timestamp'].min()) / 1000
df_stream_segment_hosted_bbb['timestamp'] = (df_stream_segment_hosted_bbb['timestamp'] - df_stream_segment_hosted_bbb['timestamp'].min())

# moq.rorre.me:8443 - chunk_duration=0.04
df_datagram_buffering_hosted_livestream['timestamp'] = (df_datagram_buffering_hosted_livestream['timestamp'] - df_datagram_buffering_hosted_livestream['timestamp'].min()) / 1000
df_datagram_segment_hosted_livestream['timestamp'] = (df_datagram_segment_hosted_livestream['timestamp'] - df_datagram_segment_hosted_livestream['timestamp'].min())

df_hybrid_buffering_hosted_livestream['timestamp'] = (df_hybrid_buffering_hosted_livestream['timestamp'] - df_hybrid_buffering_hosted_livestream['timestamp'].min()) / 1000
df_hybrid_segment_hosted_livestream['timestamp'] = (df_hybrid_segment_hosted_livestream['timestamp'] - df_hybrid_segment_hosted_livestream['timestamp'].min())

df_stream_buffering_hosted_livestream['timestamp'] = (df_stream_buffering_hosted_livestream['timestamp'] - df_stream_buffering_hosted_livestream['timestamp'].min()) / 1000
df_stream_segment_hosted_livestream['timestamp'] = (df_stream_segment_hosted_livestream['timestamp'] - df_stream_segment_hosted_livestream['timestamp'].min())

# %%
# Create subplots for buffering metrics to compare localhost vs hosted for each type
for metric in buffering_metrics:
    fig, axes = plt.subplots(2, 2, figsize=(20, 14), sharex=True)
    fig.suptitle(f'{metric} Comparison Over Time (Localhost vs. Hosted, Livestream vs. BBB)', fontsize=16)

    # Localhost Livestream Comparison
    axes[0, 0].plot(df_datagram_buffering_localhost_livestream['timestamp'], df_datagram_buffering_localhost_livestream[metric], label='Datagram', color='blue')
    axes[0, 0].plot(df_hybrid_buffering_localhost_livestream['timestamp'], df_hybrid_buffering_localhost_livestream[metric], label='Hybrid', color='green')
    axes[0, 0].plot(df_stream_buffering_localhost_livestream['timestamp'], df_stream_buffering_localhost_livestream[metric], label='Stream', color='red')
    axes[0, 0].set_title('Localhost Livestream')
    axes[0, 0].set_ylabel(metric)
    axes[0, 0].legend()

    # Localhost BBB Comparison
    axes[0, 1].plot(df_datagram_buffering_localhost_bbb['timestamp'], df_datagram_buffering_localhost_bbb[metric], label='Datagram', color='blue')
    axes[0, 1].plot(df_hybrid_buffering_localhost_bbb['timestamp'], df_hybrid_buffering_localhost_bbb[metric], label='Hybrid', color='green')
    axes[0, 1].plot(df_stream_buffering_localhost_bbb['timestamp'], df_stream_buffering_localhost_bbb[metric], label='Stream', color='red')
    axes[0, 1].set_title('Localhost BBB')
    axes[0, 1].legend()

    # Hosted Livestream Comparison
    # axes[1, 0].plot(df_datagram_buffering_hosted_livestream['timestamp'], df_datagram_buffering_hosted_livestream[metric], label='Datagram', color='cyan')
    # axes[1, 0].plot(df_hybrid_buffering_hosted_livestream['timestamp'], df_hybrid_buffering_hosted_livestream[metric], label='Hybrid', color='lightgreen')
    # axes[1, 0].plot(df_stream_buffering_hosted_livestream['timestamp'], df_stream_buffering_hosted_livestream[metric], label='Stream', color='orange')
    # axes[1, 0].set_title('Hosted Livestream')
    # axes[1, 0].set_xlabel('Timestamp (seconds)')
    # axes[1, 0].set_ylabel(metric)
    # axes[1, 0].legend()

    # # Hosted BBB Comparison
    # axes[1, 1].plot(df_datagram_buffering_hosted_bbb['timestamp'], df_datagram_buffering_hosted_bbb[metric], label='Datagram', color='cyan')
    # axes[1, 1].plot(df_hybrid_buffering_hosted_bbb['timestamp'], df_hybrid_buffering_hosted_bbb[metric], label='Hybrid', color='lightgreen')
    # axes[1, 1].plot(df_stream_buffering_hosted_bbb['timestamp'], df_stream_buffering_hosted_bbb[metric], label='Stream', color='orange')
    # axes[1, 1].set_title('Hosted BBB')
    # axes[1, 1].set_xlabel('Timestamp (seconds)')
    # axes[1, 1].legend()

    # Adjust layout and show the plots
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.show()

    # Save the plots
    os.makedirs('./plots/buffering', exist_ok=True)
    fig.savefig(f'./plots/buffering/{metric}_comparison.png')

# %%
for metric in segment_metrics:
    fig, axes = plt.subplots(2, 2, figsize=(20, 14), sharex=True)
    fig.suptitle(f'{metric} Comparison Over Segments (Localhost vs. Hosted, Livestream vs. BBB)', fontsize=16)

    # Localhost Livestream Comparison
    axes[0, 0].plot(df_datagram_segment_localhost_livestream[metric], label='Datagram', color='blue')
    axes[0, 0].plot(df_hybrid_segment_localhost_livestream[metric], label='Hybrid', color='green')
    axes[0, 0].plot(df_stream_segment_localhost_livestream[metric], label='Stream', color='red')
    axes[0, 0].set_title('Localhost Livestream')
    axes[0, 0].set_ylabel(metric)
    axes[0, 0].legend()

    # Localhost BBB Comparison
    axes[0, 1].plot(df_datagram_segment_localhost_bbb[metric], label='Datagram', color='blue')
    axes[0, 1].plot(df_hybrid_segment_localhost_bbb[metric], label='Hybrid', color='green')
    axes[0, 1].plot(df_stream_segment_localhost_bbb[metric], label='Stream', color='red')
    axes[0, 1].set_title('Localhost BBB')
    axes[0, 1].legend()

    # Hosted Livestream Comparison
    # axes[1, 0].plot(df_datagram_segment_hosted_livestream[metric], label='Datagram', color='cyan')
    # axes[1, 0].plot(df_hybrid_segment_hosted_livestream[metric], label='Hybrid', color='lightgreen')
    # axes[1, 0].plot(df_stream_segment_hosted_livestream[metric], label='Stream', color='orange')
    # axes[1, 0].set_title('Hosted Livestream')
    # axes[1, 0].set_xlabel('Segments')
    # axes[1, 0].set_ylabel(metric)
    # axes[1, 0].legend()

    # # Hosted BBB Comparison
    # axes[1, 1].plot(df_datagram_segment_hosted_bbb[metric], label='Datagram', color='cyan')
    # axes[1, 1].plot(df_hybrid_segment_hosted_bbb[metric], label='Hybrid', color='lightgreen')
    # axes[1, 1].plot(df_stream_segment_hosted_bbb[metric], label='Stream', color='orange')
    # axes[1, 1].set_title('Hosted BBB')
    # axes[1, 1].set_xlabel('Segments')
    # axes[1, 1].legend()

    # Adjust layout and show the plots
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.show()

    # Save the plots
    os.makedirs('./plots/segment', exist_ok=True)
    fig.savefig(f'./plots/segment/{metric}_comparison.png')
